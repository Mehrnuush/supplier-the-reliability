# %%
import pandas as pd

df=pd.read_csv('data_ago_strategos_strateng_20220216_1.csv')  
df.describe()
df.head(5)
# Out:
#        Time                 Supplier  ...   Theor_Lead Time   Accepted_0_1
# 0  1.111347   Delivery by Eagle Bull  ...                3.9            Ok
# 1  1.133971  Delivery by Majora Cola  ...                4.0            Ok
# 2  1.280148  Delivery by Blue Orange  ...                3.2            Ok
# 3  1.367357  Delivery by Blue Orange  ...                3.2            Ok
# 4  1.372985  Delivery by Blue Orange  ...                3.2            Ok
#
# [5 rows x 5 columns]

# %%
df.Supplier.unique()
# Out:
# array(['Delivery by Eagle Bull', 'Delivery by Majora Cola',
#        'Delivery by Blue Orange', 'Delivery by Cora-Cora',
#        'Delivery by Chicken-Cola', 'Delivery by Yellow Bear',
#        'Delivery by Royal Drinks'], dtype=object)

# %%
df2=df.groupby(["Supplier"])[" Actual_Lead_Time "]
df3=df.groupby(["Supplier"])[" Theor_Lead Time "].mean()

# %%
import matplotlib.pyplot as plt
#plt.plot(df2)
#plt.plot(df3)
#df.plot.bar(rot=15, rision for Sedans made by a Car Company");


df2.plot.bar()

df3.plot.bar()


#plot.show(block=True);
#df2.plot(kind="bar")

# %%
df3.plot.kde()

# %%
df2.plot.kde()
# Out:
# Supplier
# Delivery by Blue Orange     AxesSubplot(0.125,0.125;0.775x0.755)
# Delivery by Chicken-Cola    AxesSubplot(0.125,0.125;0.775x0.755)
# Delivery by Cora-Cora       AxesSubplot(0.125,0.125;0.775x0.755)
# Delivery by Eagle Bull      AxesSubplot(0.125,0.125;0.775x0.755)
# Delivery by Majora Cola     AxesSubplot(0.125,0.125;0.775x0.755)
# Delivery by Royal Drinks    AxesSubplot(0.125,0.125;0.775x0.755)
# Delivery by Yellow Bear     AxesSubplot(0.125,0.125;0.775x0.755)
# Name:  Actual_Lead_Time , dtype: object

# %%
df2.plot.density()
# Out:
# Supplier
# Delivery by Blue Orange     AxesSubplot(0.125,0.125;0.775x0.755)
# Delivery by Chicken-Cola    AxesSubplot(0.125,0.125;0.775x0.755)
# Delivery by Cora-Cora       AxesSubplot(0.125,0.125;0.775x0.755)
# Delivery by Eagle Bull      AxesSubplot(0.125,0.125;0.775x0.755)
# Delivery by Majora Cola     AxesSubplot(0.125,0.125;0.775x0.755)
# Delivery by Royal Drinks    AxesSubplot(0.125,0.125;0.775x0.755)
# Delivery by Yellow Bear     AxesSubplot(0.125,0.125;0.775x0.755)
# Name:  Actual_Lead_Time , dtype: object

# %%
df.groupby(["Supplier"])[" Theor_Lead Time "].hist()
# Out:
# Supplier
# Delivery by Blue Orange     AxesSubplot(0.125,0.125;0.775x0.755)
# Delivery by Chicken-Cola    AxesSubplot(0.125,0.125;0.775x0.755)
# Delivery by Cora-Cora       AxesSubplot(0.125,0.125;0.775x0.755)
# Delivery by Eagle Bull      AxesSubplot(0.125,0.125;0.775x0.755)
# Delivery by Majora Cola     AxesSubplot(0.125,0.125;0.775x0.755)
# Delivery by Royal Drinks    AxesSubplot(0.125,0.125;0.775x0.755)
# Delivery by Yellow Bear     AxesSubplot(0.125,0.125;0.775x0.755)
# Name:  Theor_Lead Time , dtype: object

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f27624d5410>,
# ...
#       dtype=object)

# %%
df.groupby(["Supplier"])[" Actual_Lead_Time "].describe()
# Out:
#                           count      mean       std  ...     50%      75%     max
# Supplier                                             ...
# Delivery by Blue Orange   588.0  3.301350  0.870084  ...  3.2660  3.78125   6.538
# Delivery by Chicken-Cola  549.0  4.545246  0.833428  ...  4.4290  4.85800   7.134
# Delivery by Cora-Cora     568.0  4.290956  0.854662  ...  4.2465  4.77775   7.076
# Delivery by Eagle Bull    582.0  4.020775  0.616955  ...  3.9195  4.30550   7.008
# Delivery by Majora Cola   581.0  4.327821  0.865565  ...  4.1850  4.74100   7.132
# Delivery by Royal Drinks  553.0  4.460396  0.935798  ...  4.3210  5.21700   6.841
# Delivery by Yellow Bear   579.0  6.145986  1.120434  ...  6.0800  6.80700  10.310
#
# [7 rows x 8 columns]
